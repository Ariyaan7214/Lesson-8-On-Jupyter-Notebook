# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install numpy

# %%
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x , y, 'darkviolet')
plt.xlabel('AGE ')
plt.ylabel('NETWORTH ')
plt.title('AGE:NETWORTH')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
fig,ax =
plt.subplots(figsize=(12,6))

ax.plot()
# Out:
#   File "C:\Users\Volkan\AppData\Local\Temp\ipykernel_9496\1316895418.py", line 1
#     fig,ax =
#             ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)
# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')
# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='x')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='*')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='D')
# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [raw]
# fig, ax = plt.subplots(figsize=(22,11))
#
# ax.plot(x, x+1, color="pink", linewidth=0.5)
# ax.plot(x, x+2, color="purple", linewidth=1)
# ax.plot(x, x+3, color="navy", linewidth=1.5)
# ax.plot(x, x+4, color="orange", linewidth=2)
#
# ax.plot(x, x+5, color="torquise", lw=3, linestyle='.')
# ax.plot(x, x+6, color="red", lw=4, ls='-')
# ax.plot(x, x+7, color="brown", lw=5, ls=':')
#
# ax.plot(x, x+ 9, color="black", lw=6.5, ls='-:', marker='')
# ax.plot(x, x+10, color="red", lw=8, ls=';', marker='')
# ax.plot(x, x+11, color="purple", lw=9.5, ls='.:', marker='')
# ax.plot(x, x+12, color="blue", lw=11, ls='-;', marker='')
#
# ax.plot(x, x+13, color="torquise", lw=13, ls=':;', marker='', markersize=)
# ax.plot(x, x+14, color="sky blue", lw=15, ls='-.', marker='', markersize=)
# ax.plot(x, x+15, color="blue", lw=17, ls='.;', marker='', markersize=, markerfacecolor="")
# ax.plot(x, x+16, color="navy", lw=19, ls='', marker='', markersize=, markerfacecolor="", markeredgewidth=, markeredgecolor="");
